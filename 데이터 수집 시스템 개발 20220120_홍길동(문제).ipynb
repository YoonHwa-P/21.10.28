# %% [markdown]
# # 개요
# - 교과목: 빅데이터 시스템 개발
# - 능력단위: 빅데이터 수집시스템 개발
# - 훈련교사명: 정지훈 강사
# - 수강생명: 전우정
# - 평가방법: 기타(작업형)
# - 평가예정일: 2022년 01월 20일 목요일 (1시간)

# %% [markdown]
# # 출제 문항
# - 네이버 뉴스 데이터의 댓글을 수집하는 코드를 완성하세요.
#   + 뉴스기사: https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=105&oid=009&aid=0004909400

# %% [markdown]
# # 답안 코드

# %%
# (1) 크롤링 라이브러리

# 샘플 URL을 적용한다. 
url = "https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=105&oid=009&aid=0004909400" 

def get_df(url):
  # 댓글을 달 빈 리스트를 생성합니다.
  List = []
  url = url
  # (2) URL 주소에서 oid만 추출하기
  # 

  # (3) URL 주소에서 aid만 추출하기
  page = 1
  header = {
        "User-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36",
        "referer": url,
  }
  while True:
    c_url = "https://apis.naver.com/commentBox/cbox/web_neo_list_jsonp.json?ticket=news&templateId=default_society&pool=cbox5&_callback=jQuery1707138182064460843_1523512042464&lang=ko&country=&objectId=news" + oid + "%2C" + aid + "&categoryId=&pageSize=20&indexSize=10&groupId=&listType=OBJECT&pageType=more&page=" + str(
          page) + "&refresh=false&sort=FAVORITE"
    # 파싱하는 단계입니다.

    # (4) 상태코드 출력하기
    
    # (5) BeautifulSoup를 활용하여 html 파싱하기

    # (6) 전체 댓글 개수 출력하기

    match = re.findall('"contents":([^\*]*),"userIdNo"', str(cont))
    
    # (7) 댓글을 리스트에 중첩합니다.

    # 한번에 댓글이 20개씩 보이기 때문에 한 페이지씩 몽땅 댓글을 긁어 옵니다.
    if int(total_comm) <= ((page) * 20):
      break
    else:
      page += 1

		# 
  def flatten(l):
    flatList = []
    for elem in l:
      if type(elem) == list:
        for e in elem:
          flatList.append(e)
      else:
        flatList.append(elem)
    return flatList

  # 리스트 결과입니다.
  # print(flatten(List))

  # convert dataframe
  # (8) 수집된 댓글을 pandas 데이터 프레임으로 변환하기

  # write_excel
  # data.to_excel("news_comments.xlsx", sheet_name="Sheet1")
  return data

data = get_df(url) # URL 테스트 시, 실행

# (9) 결과물을 엑셀 시트로 내보내기
# data.to_excel("news_comments.xlsx", sheet_name="Sheet1")

# 결과물 예시
data
# Out:
#     index                                               기사댓글
# 0       0               "드디어!! 애플로 갈아타려다 기다린 보람이 있네요~~ 야호!!"
# 1       1                                    "갤럭시노트  정말 유용."
# 2       2                                      "설레일것 까지야 ㅋㅋ"
# 3       3                                      "애플은 앞으로 안쓴다"
# 4       4  "노트 시리즈를 따로 가지말고  S시리즈에 통합해라. 그래서 천천히 더 좋게 개발해라."
# ..    ...                                                ...
# 79     79                        "아이폰은 배터리 개선전까지는 삼성을 이길수없다"
# 80     80                          "디자인이 왜 저따구냐 ㅋ 전혀 사고싶지않네"
# 81     81                   "노트 ㅋ 펜 활용도가 얼마나 있나?? 극히 소수아님??"
# 82     82                                   "아이폰은 좌파애들이 좋아함"
# 83     83  "애플 아이폰 연간 판매량 2억대 vs 삼성 폴드 플립 400만대 + S시리즈 11...
#
# [84 rows x 2 columns]

# %%
#
